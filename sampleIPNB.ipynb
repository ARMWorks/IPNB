# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.xkcd()

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2)*(1/(x+1)**2))
plt.title('Escape to the 3rd Dimension!');
